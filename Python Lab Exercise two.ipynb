# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.read_csv('heart.csv')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_df = pd.read_csv('heart.csv')

# %%
age_series = heart_df['age']
age_series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
heart_df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
age_series.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
heart_df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
sns.set_style('darkgrid')
sns.histplot(data=heart_df['age'], kde=True);

# %%
sns.scatterplot(x=heart_df['age'], y=heart_df['thalach']);

# %%
extra_rows = {'age': [40, 30], 'sex': [1, 0], 'cp': [0, 0], 'trestbps': [120, 130],
              'chol': [240, 200],
             'fbs': [0, 0], 'restecg': [1, 0], 'thalach': [120, 122], 'exang': [0, 1],
              'oldpeak': [0.1, 1.0], 'slope': [1, 1], 'ca': [0, 1], 'thal': [2, 3],
              'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %%
missing = pd.DataFrame(extra_rows)
missing
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   40    1   0       120   240    0        1      120      0      0.1      1
# 1   30    0   0       130   200    0        0      122      1      1.0      1
#
#    ca  thal  target
# 0   0     2       0
# 1   1     3       0

# %%
pd.DataFrame.from_dict(heart_df)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_augmented = pd.concat([heart_df, missing],
                           ignore_index=True)
heart_augmented
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_augmented.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
# 303      1   0     2       0
# 304      1   1     3       0

# %%
heart_augmented.info
# Out:
# <bound method DataFrame.info of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target  test  chol+trestbps
# ...

# %%
heart_augmented['test'] = 0
heart_augmented.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test
# 0   0     1       1     0
# 1   0     2       1     0
# 2   0     2       1     0
# 3   0     2       1     0
# 4   0     2       1     0

# %%
heart_augmented.dtypes
# Out:
# age                int64
# sex                int64
# cp                 int64
# trestbps           int64
# chol               int64
# fbs                int64
# restecg            int64
# thalach            int64
# exang              int64
# oldpeak          float64
# slope              int64
# ca                 int64
# thal               int64
# target             int64
# test               int64
# chol+trestbps      int64
# dtype: object

# %%
heart_augmented['chol+trestbps'] = heart_augmented['chol'] + heart_augmented['trestbps']
heart_augmented.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test  chol+trestbps
# 0   0     1       1     0            378
# 1   0     2       1     0            380
# 2   0     2       1     0            334
# 3   0     2       1     0            356
# 4   0     2       1     0            474

# %%
heart_augmented['age'] >= 70
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# Name: age, Length: 305, dtype: bool

# %%
heart_augmented[heart_augmented['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target  test  chol+trestbps
# 25       2   2     2       1     0            462
# 60       2   1     2       1     0            375
# ...

# %%
heart_augmented[heart_augmented['trestbps'] >= 170]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 152   64    1   3       170   227    0        0      155      0      0.6
# 195   59    1   0       170   326    0        0      140      1      3.4
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# 228   59    1   3       170   288    0        0      159      0      0.2
# 241   59    0   0       174   249    0        1      143      1      0.0
# 248   54    1   1       192   283    0        0      195      0      0.0
# 260   66    0   0       178   228    1        1      165      1      1.0
# 266   55    0   0       180   327    0        2      117      1      3.4
# ...

# %%
both_age_trestbps = heart_augmented[(heart_augmented['age'] >= 70) & (heart_augmented['trestbps'] > 170)]
both_age_trestbps
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target, test, chol+trestbps]
# Index: []

# %%
at_risk = both_age_trestbps
sns.scatterplot(data=at_risk, x='age', y='chol', hue='sex');

# %%
both_age_chol = heart_augmented[(heart_augmented['age'] >= 70) & (heart_augmented['chol'] > 170)]
both_age_chol
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target  test  chol+trestbps
# 25       2   2     2       1     0            462
# 60       2   1     2       1     0            375
# 129      2   1     2       1     0            389
# ...

# %%
at_risk = both_age_chol
sns.scatterplot(data=at_risk, x='age', y='chol', hue='sex');

# %%
heart_augmented.loc

# %%
heart_augmented.loc[:9, ['age', 'trestbps']]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %%
heart_augmented.iloc

# %%
heart_augmented.iloc[3, 0]
# Out:
# 56

# %%
heart_augmented.iloc[0:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target  test  chol+trestbps
# 0   0     1       1     0            378
# 1   0     2       1     0            380
# 2   0     2       1     0            334
# 3   0     2       1     0            356

# %%
heart_augmented.iloc[0:10, [0, 3]]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %%
heart_augmented.mean()
# Out:
# age               54.239344
# sex                0.681967
# cp                 0.960656
# trestbps         131.580328
# chol             246.091803
# fbs                0.147541
# restecg            0.527869
# thalach          149.459016
# exang              0.327869
# oldpeak            1.036393
# slope              1.396721
# ca                 0.727869
# thal               2.314754
# target             0.540984
# test               0.000000
# chol+trestbps    377.672131
# dtype: float64

# %%
heart_augmented.min()
# Out:
# age               29.0
# sex                0.0
# cp                 0.0
# trestbps          94.0
# chol             126.0
# fbs                0.0
# restecg            0.0
# thalach           71.0
# exang              0.0
# oldpeak            0.0
# slope              0.0
# ca                 0.0
# thal               0.0
# target             0.0
# test               0.0
# chol+trestbps    249.0
# dtype: float64

# %%
heart_augmented.max()
# Out:
# age               77.0
# sex                1.0
# cp                 3.0
# trestbps         200.0
# chol             564.0
# fbs                1.0
# restecg            2.0
# thalach          202.0
# exang              1.0
# oldpeak            6.2
# slope              2.0
# ca                 4.0
# thal               3.0
# target             1.0
# test               0.0
# chol+trestbps    679.0
# dtype: float64

# %%
slopez = heart_augmented['slope'].value_counts()
slopez
# Out:
# 2    142
# 1    142
# 0     21
# Name: slope, dtype: int64

# %%
heart_augmented['sex'].value_counts()
# Out:
# 1    208
# 0     97
# Name: sex, dtype: int64

# %%
heart_augmented['target'].value_counts()
# Out:
# 1    165
# 0    140
# Name: target, dtype: int64

# %%
heart_augmented['age'].sort_values()
# Out:
# 72     29
# 304    30
# 58     34
# 125    34
# 65     35
#        ..
# 25     71
# 60     71
# 129    74
# 144    76
# 238    77
# Name: age, Length: 305, dtype: int64

# %%
agez= heart_augmented['age']
agez
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 300    68
# 301    57
# 302    57
# 303    40
# 304    30
# Name: age, Length: 305, dtype: int64

# %%
heart_augmented.plot(x='age', y='trestbps', kind='scatter');

# %%
heart_augmented[heart_augmented['trestbps'] >= 170]

# %%
heart_augmented.hist(column='chol');

# %%
age_countz = pd.DataFrame(heart_augmented['age'].value_counts())
age_countz
# Out:
#     age
# 58   19
# 57   17
# 54   16
# 59   14
# 52   13
# 51   12
# 56   11
# 44   11
# 60   11
# 62   11
# 41   10
# 64   10
# 67    9
# 63    9
# 43    8
# 53    8
# 42    8
# 61    8
# 55    8
# 45    8
# 65    8
# 48    7
# 46    7
# 50    7
# 66    7
# 49    5
# 47    5
# 68    4
# 39    4
# 35    4
# 70    4
# 40    4
# 69    3
# 38    3
# 71    3
# 37    2
# 34    2
# 74    1
# 76    1
# 29    1
# 77    1
# 30    1

# %%
slope_countz = pd.DataFrame(heart_augmented['slope'].value_counts())
slope_countz
# Out:
#    slope
# 2    142
# 1    142
# 0     21

# %%
age_slopez = heart_augmented.loc[:304, ['slope', 'age']]
age_slopez
# Out:
#      slope  age
# 0        0   63
# 1        0   37
# 2        2   41
# 3        2   56
# 4        2   57
# ..     ...  ...
# 300      1   68
# 301      1   57
# 302      1   57
# 303      1   40
# 304      1   30
#
# [305 rows x 2 columns]

# %%
number_of_age_slopez = age_slopez.value_counts()
number_of_age_slopez
# Out:
# slope  age
# 1      57     10
#        58     10
# 2      52      9
#        54      8
#        58      8
#               ..
# 1      47      1
# 0      42      1
# 1      71      1
#        76      1
# 2      77      1
# Length: 93, dtype: int64

# %%
both_age_slope = pd.DataFrame(heart_augmented.groupby(['age'])['slope'].count())
both_age_slope
# Out:
#      slope
# age
# 29       1
# 30       1
# 34       2
# 35       4
# 37       2
# 38       3
# 39       4
# 40       4
# 41      10
# 42       8
# 43       8
# 44      11
# 45       8
# 46       7
# 47       5
# 48       7
# 49       5
# 50       7
# 51      12
# 52      13
# 53       8
# 54      16
# 55       8
# 56      11
# 57      17
# 58      19
# 59      14
# 60      11
# 61       8
# 62      11
# 63       9
# 64      10
# 65       8
# 66       7
# 67       9
# 68       4
# 69       3
# 70       4
# 71       3
# 74       1
# 76       1
# 77       1

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
slopez = ['0','1','2','3']
age = [29,30,31,31]
ax.bar(slopez,age)
plt.show()

# %%
plt.hist(heart_augmented)
plt.xlabel('sex')
plt.ylabel('age')
plt.title(Male)
